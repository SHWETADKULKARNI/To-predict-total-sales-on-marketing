# %% [markdown]
# ## To predict total sales by using features like money spent on marketing on individual items

# %% [markdown]
# ### Linear Regression Task

# %% [markdown]
# ## Domain analysis

# %%
1) TV :-Amount spend on TV advertisement. 
2) Radio:- Amount spend on Radio.
3) Newspaper:- Amount spend on Newspaper.
4) Sales:- Sales of product.
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp/ipykernel_9440/494026336.py", line 1
#     1)TV :-Amount spend on TV advertisement.
#      ^
# SyntaxError: unmatched ')'

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading the data
data=pd.read_csv('Advertising.csv')

# %%
#call the dataframe & do basic checks
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [raw]
# 1) The distribution of TV advertisement have more spread as compare to others.
# 2) In once case the company has spend 0 dollars for advertising on Radio.
# 3) The cost of advertisement on radio is less while for TV is high.

# %%
data.info()
#no missing values in data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# # Exploratory Data Analysis

# %%
#step 1-univeriate analysis
# Analyzing TV
sns.histplot(x='TV',data=data)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Count'>

# %%
sns.displot(x=data.TV,kde=True)

# %%
#Analyzing Radio
sns.histplot(x=data.Radio,kde=True)
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Count'>

# %%
#Analyzing Newspaper
sns.histplot(x=data.Newspaper,kde=True)
#by looking at below plot we can say that there are less than 10 days when the marketing cost was high.
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Count'>

# %%
# step 2:- Bivariant Analysis
# This step is performed when inputs & output are known.
#1st variable will be Inputs.
#2nd variable will be output/target variable.

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Analysing TV and Sales
sns.relplot(x='TV',y='Sales',data=data)
# The more marketing on TV is leading to more sales in the product.

# %%
plt.plot(data.TV)
plt.plot(data.Sales)

# %%
# Analysing Radio & Sales
sns.relplot(x='Radio',y='Sales',data=data)
# Radio Advertisement are not showing much trend for the sales of product.

# %%
# Analysing Newspaper & Sales
sns.relplot(x='Newspaper',y='Sales',data=data)
# Newspaper Advertisement are not showing much trend for the sales of product.

# %%
##step 3 :- Multivarient Analyzing
sns.pairplot(data)

# %% [markdown]
# ## Data Preprocessing & Feature Engineering

# %%
# step 1:- Finding missing values
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
# step 2:- converting categorical data to numerical

# %%
# step 3:- checking outlier
sns.boxplot(x='TV',data=data)
# Out:
# <AxesSubplot:xlabel='TV'>

# %%
sns.boxplot(x='Radio',data=data)
# Out:
# <AxesSubplot:xlabel='Radio'>

# %%
sns.boxplot(x='Newspaper',data=data)
# Out:
# <AxesSubplot:xlabel='Newspaper'>

# %%
# step 4:- scaling the continuous variable 
intensionally skipping this step
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp/ipykernel_9440/3656572245.py", line 2
#     intensionally skipping this step
#                   ^
# SyntaxError: invalid syntax

# %%
# step 5:- Transformation
Intentionally skipping this step
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp/ipykernel_9440/1229489729.py", line 2
#     Intentionally skipping this step
#                   ^
# SyntaxError: invalid syntax

# %%
# step 6:- Balancing the data
This step is performed specially for classification

# %% [markdown]
# # Feature selection

# %%
# step 1:- dropping the unwanted variables
l1=['Unnamed: 0']
data.drop(l1,axis=1,inplace=True)

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
#step 2:- checking the correlation
sns.heatmap(data.drop('Sales',axis=1).corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Creation

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Step 1:- Independent & dependent variable creation 
x=data[['TV','Radio','Newspaper']]  ## X variable contains all inputs
y=data.Sales ## y is output

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# step 2:- Training & testing data creation
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 26   142.9   29.3       12.6
# 134   36.9   38.6       65.6
# 180  156.6    2.6        8.3
# 158   11.7   36.9       45.2
# 189   18.7   12.1       23.4
# ..     ...    ...        ...
# 104  238.2   34.3        5.3
# 129   59.6   12.0       43.1
# 183  287.6   43.0       71.8
# 174  222.4    3.4       13.1
# 122  224.0    2.4       15.6
#
# [160 rows x 3 columns]

# %%
y_train
# Out:
#         TV  Radio  Newspaper
# 11   214.7   24.0        4.0
# 99   135.2   41.7       45.9
# 128  220.3   49.0        3.2
# 175  276.9   48.9       41.8
# 1     44.5   39.3       45.1
# 111  241.7   38.0       23.2
# 90   134.3    4.9        9.3
# 177  170.2    7.8       35.2
# 88    88.3   25.5       73.4
# 187  191.1   28.7       18.2
# 61   261.3   42.7       54.7
# 199  232.1    8.6        8.7
# 191   75.5   10.8        6.0
# 123  123.1   34.6       12.4
# 184  253.8   21.3       30.0
# 188  286.0   13.9        3.7
# 33   265.6   20.0        0.3
# 171  164.5   20.9       47.4
# 138   43.0   25.9       20.5
# 84   213.5   43.0       33.8
# 81   239.8    4.1       36.9
# 102  280.2   10.1       21.4
# 147  243.2   49.0       44.3
# 34    95.7    1.4        7.4
# 47   239.9   41.5       18.5
# 124  229.5   32.3       74.2
# 112  175.7   15.4        2.4
# 6     57.5   32.8       23.5
# 14   204.1   32.9       46.0
# 190   39.5   41.1        5.8
# 80    76.4   26.7       22.3
# ...

# %%
#step 3:-creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression()   #object creation
LR.fit(x_train,y_train) #training of linear regression
y_predict=LR.predict(x_test)

# %%
y_test ##actual values
# Out:
# 11     17.4
# 99     17.2
# 128    24.7
# 175    27.0
# 1      10.4
# 111    21.8
# 90     11.2
# 177    11.7
# 88     12.9
# 187    17.3
# 61     24.2
# 199    13.4
# 191     9.9
# 123    15.2
# 184    17.6
# 188    15.9
# 33     17.4
# 171    14.5
# 138     9.6
# 84     21.7
# 81     12.3
# 102    14.8
# 147    25.4
# 34      9.5
# 47     23.2
# 124    19.7
# 112    14.1
# 6      11.8
# 14     19.0
# 190    10.8
# 80     11.8
# 18     11.3
# 167    12.2
# 45     14.9
# 153    19.0
# 119     6.6
# 100    11.7
# 83     13.6
# 181    12.2
# 71     12.4
# Name: Sales, dtype: float64

# %%
y_predict #values predicted by model
# Out:
# array([17.2752476 , 16.74844593, 21.97674588, 24.59448907, 12.11768831,
#        21.02033688, 10.15643252, 12.34380805, 11.70461016, 17.02091374,
#        22.77376935, 15.3468411 ,  8.47830473, 14.9155752 , 18.61592987,
#        18.78535771, 18.92262443, 14.411111  ,  9.65948532, 20.60497137,
#        14.91294261, 17.84682569, 23.05099966,  7.74477655, 21.55734502,
#        19.45793001, 13.93893979, 11.55855542, 18.37843109, 12.19352005,
#        11.35032808,  9.91369153, 13.57335272, 15.18177818, 18.06379607,
#         6.80705318, 14.14598886, 14.14649594, 14.1536933 , 10.69806825])

# %%
# step :-model evaluation

from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_predict)

# %%
r2score
# Out:
# 0.9085774752313167

# %%
x_test.shape
# Out:
# (40, 3)

# %%
## calculation of adjusted r2 score
adjusted_r2= 1-(1-0.90)*(40-3)/(40-3-1)
adjusted_r2
# Out:
# 0.8972222222222223

# %%
import math 
print(mean_squared_error(y_test,y_predict))
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 2.2171510725418964
# 1.4890100982001084

# %%
print(mean_absolute_error(y_test,y_predict))
# Out:
# 1.2114892606469105
